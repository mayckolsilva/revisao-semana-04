# %%
# importação de biblioteca
import re
from datetime import datetime

# %%
#função para converter o valor
def converter_valor(valor): #1.250,00   
    valor = valor.replace(".","") # 1250,50
    valor = valor.replace(",",".")# 1250.50

    return float(valor)

# %%
# função para converter data
def converter_data(data):
    return datetime.strptime(data,"%d/%m/%Y")

# %%
# Função para processar cada linha do relatório
def processar_linha(linha):

    # Ignorar cancelados
    if "CANCELADO" in linha:
        return None
    
    # Encontrar padrões
    padrao = (
        r"Pedido #(\d+)\s*\|\s*"
        r"Data=(\d{2}/\d{2}/\d{4})\s*\|\s*"
        r"Cliente:\s*(.*?)\s*\|\s*"
        r"Valor:\s*R\$\s*([\d.,]+)"
    )

    resultado = re.search(padrao, linha)

    if resultado is None:
        return None

    pedido,data,cliente,valor = resultado.groups()

    return {
        "pedido": int(pedido),
        "data": converter_data(data),
        "cliente": cliente,
        "valor": converter_valor(valor)
    }

# %%
# Lendo o Arquivo
vendas = []
with open("vendas_julho.txt", "r", encoding="utf-8") as arquivo:
    for linha in arquivo:
        venda = processar_linha(linha)

        if venda:
            vendas.append(venda)

# %%
# Exibindo as vendas

for venda in vendas:
    print(
        venda["pedido"],
        venda["data"].strftime("%d/%m/%Y"),
        venda["cliente"],
        f"R$ {venda["valor"]}"
    )
# Out:
# 1001 01/07/2026 João Silva R$ 1250.5
# 1002 02/07/2026 Maria Souza R$ 899.9
# 1003 03/07/2026 Carlos Lima R$ 2100.0
# 1005 03/07/2026 Pedro Santos R$ 799.9
# 1006 06/07/2026 Fernanda Alves R$ 1580.0
# 1007 07/07/2026 Lucas Pereira R$ 320.5
# 1008 08/07/2026 Mariana Rocha R$ 2450.0
# 1009 09/07/2026 Rafael Lima R$ 980.0
# 1010 10/07/2026 Juliana Martins R$ 3150.75
# 1012 13/07/2026 Camila Fernandes R$ 670.0
# 1013 15/07/2026 Eduardo Gomes R$ 2890.4
# 1014 15/07/2026 Paula Oliveira R$ 1050.0
# 1015 20/07/2026 Felipe Mendes R$ 540.9
# 1016 22/07/2026 Aline Ribeiro R$ 4320.0
# 1017 24/07/2026 Bruno Costa R$ 1780.0
# 1018 24/07/2026 Patrícia Lima R$ 950.5
# 1019 27/07/2026 Ricardo Alves R$ 1499.99
# 1020 27/07/2026 Vanessa Souza R$ 2050.0

# %%
# Função para calcular o total de vendas do mês
def calcular_total(vendas):
    total = 0

    for venda in vendas:
        total += venda["valor"]
    
    return total

# %%
print(f"Quantidade total de vendas: {len(vendas)}")
print(f"Valor total vendido: R$: {calcular_total(vendas)}")
